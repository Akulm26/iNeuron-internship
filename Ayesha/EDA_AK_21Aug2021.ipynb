# %% [markdown]
# ## The Hypothesis

# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import json
sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %%
data=pd.read_excel(r'CleanedData_updated.xlsx')

# %%
data_train=data[data['source']=='train']

# %%
data_train.shape
# Out:
# (8523, 13)

# %%
sns.countplot(x='Item_Fat_Content' , data=data,palette='mako')
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='count'>

# %% [markdown]
#  Most people prefer low fat product.

# %%
sns.barplot(x='Item_Fat_Content',y='Item_Outlet_Sales',data=data_train,palette='autumn')
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>

# %% [markdown]
# Though people prefer more low fat product there is not much differnce in the average sales

# %%
sns.barplot(x='Item_Fat_Content',y='Item_Outlet_Sales',data=data_train,palette='hls', estimator = np.median)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(24,8))
sns.countplot(x='Outlet_Type' , data=data,palette='tab10')
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='count'>

# %%
plt.figure(figsize=(10,5))
sns.barplot('Outlet_Type' ,'Item_Outlet_Sales', hue='Outlet_Size', data=data ,palette='nipy_spectral')
# Out:
# C:\Users\ayesha\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(10,5))
sns.barplot('Outlet_Type' ,'Item_Outlet_Sales', hue='Outlet_Location_Type', data=data ,palette='spring')
# Out:
# C:\Users\ayesha\AppData\Roaming\Python\Python37\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
data_train.groupby('Item_Identifier')['Item_Outlet_Sales'].mean().sort_values(ascending=False)
# Out:
# Item_Identifier
# FDR45    6035.310550
# NCL42    5962.017067
# FDU55    5922.457450
# FDZ50    5512.824000
# DRK23    5464.886400
#             ...
# NCN29     311.061760
# FDX10     291.121050
# FDQ04     261.437467
# FDQ60     120.509800
# NCR42     110.966667
# Name: Item_Outlet_Sales, Length: 1559, dtype: float64

# %%
data_train.groupby('Item_Identifier')['Item_Outlet_Sales'].median().sort_values(ascending=False)
# Out:
# Item_Identifier
# FDU55    5987.5394
# FDA15    5976.2208
# FDW22    5764.4964
# NCL42    5635.3312
# FDR45    5617.0217
#            ...
# NCN29     194.4136
# FDY09     175.1054
# FDQ60     120.5098
# NCR42      99.8700
# FDQ04      41.2796
# Name: Item_Outlet_Sales, Length: 1559, dtype: float64

# %%
# What you're looking for
values = data_train['Item_Identifier'].value_counts().keys().tolist()
counts = data_train['Item_Identifier'].value_counts().tolist()

# %%
sns.kdeplot(data=data_train, x="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Density'>

# %%
sns.scatterplot(data=data_train, x="Item_Weight", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Item_Weight', ylabel='Item_Outlet_Sales'>

# %%
data_train['Item_Outlet_Sales'].corr(data_train['Item_Weight'])
# Out:
# 0.013261236382299429

# %%
data_train['Item_Visibility'].corr(data_train['Item_MRP'])
# Out:
# -0.0013148480362671629

# %%
sns.scatterplot(data=data_train, x="Item_Visibility", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Item_Visibility', ylabel='Item_Outlet_Sales'>

# %%
data_train['Item_Outlet_Sales'].corr(data_train['Item_Visibility'])
# Out:
# -0.1286246122207703

# %%
sns.scatterplot(data=data_train, x="Item_Outlet_Sales", y="Item_MRP")
# Out:
# <AxesSubplot:xlabel='Item_Outlet_Sales', ylabel='Item_MRP'>

# %%
sns.scatterplot(data=data_train, x="Item_MRP", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Item_MRP', ylabel='Item_Outlet_Sales'>

# %%
data_train['Item_Outlet_Sales'].corr(data_train['Item_MRP'])
# Out:
# 0.5675744466569194

# %%
sns.scatterplot(data=data_train, x="Outlet_Establishment_Year", y="Item_Outlet_Sales")
# Out:
# <AxesSubplot:xlabel='Outlet_Establishment_Year', ylabel='Item_Outlet_Sales'>

# %%
data_train['Item_Outlet_Sales'].corr(data_train['Outlet_Establishment_Year'])
# Out:
# -0.04913497044082088

# %%
sns.boxplot(x='Outlet_Size',y='Item_Outlet_Sales',data=data_train)
# Out:
# <AxesSubplot:xlabel='Outlet_Size', ylabel='Item_Outlet_Sales'>

# %%
sns.boxplot(x='Outlet_Location_Type',y='Item_Outlet_Sales',data=data_train)
# Out:
# <AxesSubplot:xlabel='Outlet_Location_Type', ylabel='Item_Outlet_Sales'>

# %%
sns.boxplot(x='Outlet_Type',y='Item_Outlet_Sales',data=data_train)
# Out:
# <AxesSubplot:xlabel='Outlet_Type', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(24,8))
sns.boxplot(x='Item_Type',y='Item_Outlet_Sales',data=data_train)
# Out:
# <AxesSubplot:xlabel='Item_Type', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(24,8))
sns.boxplot(x='Outlet_Identifier',y='Item_Outlet_Sales',data=data_train)
# Out:
# <AxesSubplot:xlabel='Outlet_Identifier', ylabel='Item_Outlet_Sales'>

# %%
plt.figure(figsize=(24,8))
sns.boxplot(x='Item_Fat_Content',y='Item_Outlet_Sales',data=data_train)
# Out:
# <AxesSubplot:xlabel='Item_Fat_Content', ylabel='Item_Outlet_Sales'>

# %%
#data['Item_Type_Combined'] = data['Item_Identifier'].apply(lambda x: x[0:2])
#data['Item_Type_Combined'] = data['Item_Type_Combined'].map({'FD':'Food',
#                                                             'NC':'Non-Consumable',
 #                                                            'DR':'Drinks'})
#data['Item_Type_Combined'].value_counts()

# %%
#dataset['Years_Established'] = dataset['Outlet_Establishment_Year'].apply(lambda x: 2021 - x) 
#dataset = dataset.drop(columns=['Outlet_Establishment_Year'])
#dataset.head()
