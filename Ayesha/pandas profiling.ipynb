# %%
from pandas_profiling import ProfileReport
import pandas as pd
import klib

# %%
#!pip install xlrd==1.2.0
#!pip install openpyxl
# Out:
# ...
# WARNING: You are using pip version 20.2.2; however, version 21.2.4 is available.
# You should consider upgrading via the 'C:\Users\ayesha\.conda\envs\tf2\python.exe -m pip install --upgrade pip' command.
#   Using cached openpyxl-3.0.7-py2.py3-none-any.whl (243 kB)
# ...
#   Using cached et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# ...

# %%
data=pd.read_excel(r'CleanedData_updated.xlsx', engine='openpyxl')
data_train=data[data['source']=='train']

# %%
profile = ProfileReport(data_train, title="Pandas Profiling Report")

# %%
profile
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated with the `pandas-profiling` Python package&quot;&gt;&lt;meta name=author content=&quot;Simon Brugman and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.0.0&quot;&gt;&lt;meta name=url content=https://github.com/pandas-profiling/pandas-profiling&gt;&lt;meta name=date content=&quot;2021-09-02 09:34:36.351747&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %%
klib.cat_plot(data_train)
# Out:
# GridSpec(6, 8)

# %%
klib.corr_mat(data_train)
# Out:
# <style  type="text/css" >
# #T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow0_col0,#T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow0_col2,#T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow0_col4,#T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow1_col1,#T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow2_col0,#T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow2_col2,#T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow2_col3,#T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow2_col4,#T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow3_col2,#T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow3_col3,#T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow4_col0,#T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow4_col2,#T_02ec9b54_0d52_11ec_bd82_3822e2290b4erow4_col4{
#             color:  None;
# ...

# %%
klib.corr_plot(data_train)
# Out:
# <AxesSubplot:title={'center':'Feature-correlation (pearson)'}>

# %%
klib.dist_plot(data_train)
# Out:
# c:\users\ayesha\.conda\envs\tf2\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# c:\users\ayesha\.conda\envs\tf2\lib\site-packages\seaborn\distributions.py:2056: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
# c:\users\ayesha\.conda\envs\tf2\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
klib.missingval_plot(data_train)
# Out:
# No missing values found in the dataset.
